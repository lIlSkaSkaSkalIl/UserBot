# %%
# @title <center><font color="red"> 🛰️ M3U8 Telegram UserBot</font></center> { display-mode: "form" }

# Masukkan kredensial Anda di bawah ini
API_ID = 12345678           # @param {type:"integer"}
API_HASH = "your_api_hash"  # @param {type:"string"}
SESSION_STRING = "your_session_string_here"  # @param {type:"string"}

# 📁 Clone ulang repo jika ada
# !rm -rf m3u8Downloader
# !git clone https://github.com/lIlSkaSkaSkalIl/m3u8Downloader.git
# %cd m3u8Downloader

# ⚙️ Tulis file config.py
with open("config.py", "w") as f:
    f.write(f'''
API_ID = {API_ID}
API_HASH = "{API_HASH}"
SESSION_STRING = "{SESSION_STRING}"
''')

# ✅ Buat folder untuk simpan video
import os
os.makedirs("downloads", exist_ok=True)

# %%
# (Opsional) Pastikan ffmpeg tersedia
# !apt-get update -y
# !apt-get install -y ffmpeg

# Instalasi Python dependency
# !pip install -q -r requirements.txt

# %%
# 🚀 Jalankan UserBot dengan session string
# !python main.py
